# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\Folders\Coding\CPE231\SortingComparison\output\output\merge\memory.int_1_Rep_Unique_100000.txt.3.csv')
# display(df)

# %%
plt.plot(df['time'], df['heap'])
plt.plot(df['time'], df['heap_extra'])
plt.show()
